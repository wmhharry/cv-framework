# %% [markdown]
# ## 系統指令快速檢查

# %%
import subprocess

subprocess.run(["nvidia-smi"])
##!nvidia-smi ##告訴執行環境不要用 Python 直譯器執行這行，請切換到作業系統的命令列（Shell / Terminal / Bash）去執行這條系統指令。(僅限.ipynb)
# Out:
# Fri Aug 14 15:42:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.84                 Driver Version: 595.84         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off |   00000000:01:00.0  On |                  Off |
# |  0%   44C    P8             25W /  450W |    1163MiB /  24564MiB |     12%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Pytorch環境與GPU詳細資訊檢查

# %%
import os
import sys
import platform


def get_system_and_hardware_info():
    print("=" * 50)
    print("作業系統與Python環境")
    print("=" * 50)
    print(f"作業系統: {platform.system()}{platform.release()}({platform.machine()})")


get_system_and_hardware_info()
# Out:
# ...
# 作業系統與Python環境
# ...
# 作業系統: Linux6.8.0-136-generic(x86_64)
